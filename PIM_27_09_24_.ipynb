# %% [markdown]
# <a href="https://colab.research.google.com/github/R12-l/2023-Java-creando-tu-primera-aplicacion/blob/aula-1/PIM_27_09_24_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
img1 = plt.imread('/content/drive/MyDrive/Vegetable.jpg')

# %%
# imshow = para visualizar la imagen
plt.imshow(img1)
#plt.title('Vegetales')
plt.show()

# %%
print(type(img1))
# Out:
# <class 'numpy.ndarray'>

# %%
print(img1.shape)
# Out:
# (225, 225, 3)

# %%
print(img1.ndim)
# Out:
# 3

# %%
print(img1.size)
# Out:
# 151875

# %%
print(img1.dtype)
# Out:
# uint8

# %%
# Guardar imagen con otro nombre
plt.imsave('verduras.png', img1)

# %%
# Lectura de imágenes de escala de grises
img2 = plt.imread('/content/drive/MyDrive/mamografias2_png/maligno/1-1_01b8a94f493d0e4eed9235b38b327365.png')
plt.imshow(img2)

# %%
plt.imshow(img2, cmap = 'gray')
plt.show()

# %%
print(type(img2))
print(" ")
print(img2.shape)
print(" ")
print(img2.ndim)
print(" ")
print(img2.size)
print(" ")
print(img2.dtype)
# Out:
# <class 'numpy.ndarray'>
#
# (2294, 1914)
#
# 2
#
# 4390716
#
# float32

# %% [markdown]
# # **Código 2**

# %%
plt.imshow(img1)
plt.show()

# %%
print(img1)
# Out:
# [[[139  29  76]
#   [164  57 101]
#   [162  55  99]
#   ...
#   [174 135 138]
#   [172 133 136]
#   [150 130 139]]
#
#  [[162  68  14]
#   [188  95  38]
#   [183  90  31]
#   ...
#   [155 204  78]
#   [153 202  76]
#   [132 200  77]]
#
#  [[167  69  34]
#   [193  93  57]
#   [188  89  50]
#   ...
#   [153 203  88]
#   [151 201  86]
#   [129 199  87]]
#
#  ...
#
#  [[117  93  23]
#   [117 124  44]
#   [104 118  33]
#   ...
#   [209 201 178]
#   [163 220 179]
#   [182 209 168]]
#
#  [[ 99  85  12]
#   [133 144  65]
#   [110 115  35]
#   ...
#   [223 207 192]
#   [162 205 177]
#   [181 211 161]]
#
#  [[114  71  29]
#   [137 138  58]
#   [118 108  55]
#   ...
#   [178 218 165]
#   [177 204 171]
#   [185 195 160]]]

# %%
print(np.max(img1))
print(" ")
print(np.min(img1))
# Out:
# 249
#
# 0

# %%
img3 = img1.astype(np.float32)/255

# %%
print(img3)
# Out:
# [[[0.54509807 0.11372549 0.29803923]
#   [0.6431373  0.22352941 0.39607844]
#   [0.63529414 0.21568628 0.3882353 ]
#   ...
#   [0.68235296 0.5294118  0.5411765 ]
#   [0.6745098  0.52156866 0.53333336]
#   [0.5882353  0.50980395 0.54509807]]
#
#  [[0.63529414 0.26666668 0.05490196]
#   [0.7372549  0.37254903 0.14901961]
#   [0.7176471  0.3529412  0.12156863]
#   ...
#   [0.60784316 0.8        0.30588236]
#   [0.6        0.7921569  0.29803923]
#   [0.5176471  0.78431374 0.3019608 ]]
#
#  [[0.654902   0.27058825 0.13333334]
#   [0.75686276 0.3647059  0.22352941]
#   [0.7372549  0.34901962 0.19607843]
#   ...
#   [0.6        0.79607844 0.34509805]
#   [0.5921569  0.7882353  0.3372549 ]
#   [0.5058824  0.78039217 0.34117648]]
#
#  ...
#
#  [[0.45882353 0.3647059  0.09019608]
#   [0.45882353 0.4862745  0.17254902]
#   [0.40784314 0.4627451  0.12941177]
#   ...
#   [0.81960785 0.7882353  0.69803923]
#   [0.6392157  0.8627451  0.7019608 ]
#   [0.7137255  0.81960785 0.65882355]]
#
# ...

# %%
print(type(img3))
print(" ")
print(img3.shape)
print(" ")
print(img3.ndim)
print(" ")
print(img3.size)
print(" ")
print(img3.dtype)
# Out:
# <class 'numpy.ndarray'>
#
# (225, 225, 3)
#
# 3
#
# 151875
#
# float32

# %%
plt.imshow(img3)
plt.show()

# %%
print(np.max(img3))
print(" ")
print(np.min(img3))
# Out:
# 0.9764706
#
# 0.0

# %%
img4 = plt.imread('Fruit.jpg')
plt.imshow(img4)
plt.show()

# %%
print(type(img4))
print(" ")
print(img4.shape)
print(" ")
print(img4.ndim)
print(" ")
print(img4.size)
print(" ")
print(img4.dtype)
# Out:
# <class 'numpy.ndarray'>
#
# (1312, 1600, 3)
#
# 3
#
# 6297600
#
# uint8

# %%
plt.imshow(img1)
plt.show()

# %%
print(img1.shape)
# Out:
# (225, 225, 3)

# %%
# Canal Rojo
plt.imshow(img1[:,:,0], cmap = 'gray')
plt.show()

# %%
# Canal Verde
plt.imshow(img1[:,:,1], cmap = 'gray')
plt.show()

# %%
plt.imshow(img1[:,:,2], cmap = 'gray')
plt.show()

# %%
# Diferencia entre canales
diff = img1[:,:,1] - img1[:,:,2]
plt.imshow(diff, cmap = 'gray')
plt.title("Diferencia entre canal verde y azul")
plt.show()

# %%
print(diff)
# Out:
# [[209 212 212 ... 253 253 247]
#  [ 54  57  59 ... 126 126 123]
#  [ 35  36  39 ... 115 115 112]
#  ...
#  [ 70  80  85 ...  23  41  41]
#  [ 73  79  80 ...  15  28  50]
#  [ 42  80  53 ...  53  33  35]]

# %%
diff_v_r = img1[:,:,1] - img1[:,:,0]
print(diff_v_r)
# Out:
# [[146 149 149 ... 217 217 236]
#  [162 163 163 ...  49  49  68]
#  [158 156 157 ...  50  50  70]
#  ...
#  [232   7  14 ... 248  57  27]
#  [242  11   5 ... 240  43  30]
#  [213   1 246 ...  40  27  10]]

# %%
plt.imshow(diff_v_r, cmap = 'gray')
plt.title("Diferencia entre canal verde y rojo")
plt.show()

# %% [markdown]
# Interpretación:
